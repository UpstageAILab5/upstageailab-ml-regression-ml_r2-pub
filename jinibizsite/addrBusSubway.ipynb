# %% [markdown]
# ### 추가 설치 필요

# %%
# 한 번만 설치하면 되는 것들은 설치 후 주석 처리. 필요 시 주석 풀고 설치
# !pip install requests
# !pip install aiohttp
# !pip install geopy
# !pip install geopandas
# !pip install shapely
# !pip install pyproj

# %%
import pandas as pd
import numpy as np
from geopy.distance import geodesic
from shapely.geometry import Point
import geopandas as gpd
from geopandas.tools import sjoin
import pyproj
from tqdm import tqdm

# %% [markdown]
# ### 아파트와 지하철 역의 위치 데이터를 사용하여 밀도를 계산하는 함수

# %%
# bus-station density, subway-station density

#1. 아파트 위도와 경도 정보를 UTM-K 좌표계로 변환하고, 이를 기반으로 지오메트리 컬럼을 생성합니다.
def preprocess_data(df, x_col, y_col):
    wgs84 = pyproj.CRS('EPSG:4326')  # WGS84 좌표계 (위도, 경도)
    utm_k = pyproj.CRS('EPSG:5179')  # UTM-K 좌표계 (한국)
    project = pyproj.Transformer.from_crs(wgs84, utm_k, always_xy=True).transform
    
    df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
    return gpd.GeoDataFrame(df, geometry='geometry', crs=utm_k)

# 2. 위치 데이터를 사용하여 주어진 반경 내의 밀도를 계산합니다.
def calculate_density(gdf_real_estate, gdf_locations, radius):
    gdf_real_estate['buffer'] = gdf_real_estate.geometry.buffer(radius)
    
    joined = sjoin(gdf_locations, gdf_real_estate.set_geometry('buffer'), how='inner', predicate='within')
    
    density = joined.groupby(joined.index_right).size().rename('density')
    
    return gdf_real_estate.join(density, how='left').fillna(0)['density']


# 큰 데이터프레임을 작은 청크로 나누어 처리하여 메모리 사용을 최적화
def process_in_chunks(df, locations_gdf, radius, chunk_size=10000):
    results = []
    for i in tqdm(range(0, len(df), chunk_size)):
        chunk = df.iloc[i:i+chunk_size]
        chunk_gdf = preprocess_data(chunk, '좌표X', '좌표Y')
        density = calculate_density(chunk_gdf, locations_gdf, radius)
        results.append(density)
    return pd.concat(results)

# %% [markdown]
# ### 데이터 로드

# %%
path = '../trainTestLatLng.csv'
bus_path  = '../bus_feature.csv'
subway_path  = '../subway_feature.csv'

# train + test + 결측치 채운값
concat = pd.read_csv(path, index_col=0)
#버스
dt_bus = pd.read_csv(bus_path)
#지하철
dt_subway = pd.read_csv(subway_path)
# Out:
# /tmp/ipykernel_495348/854141158.py:6: DtypeWarning: Columns (14,15,17,18,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   concat = pd.read_csv(path, index_col=0)

# %%
display(len(concat))
display(concat.head(1))
display(dt_bus.head(1))
display(dt_subway.head(1))
# Out:
# 1128094
#              시군구     번지     본번   부번    아파트명   전용면적    계약년월  계약일  층  건축년도  ...  \
# 0  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  79.97  201712    8  3  1987  ...
#
#     주차대수  기타/의무/임대/임의=1/2/3/4                  단지승인일 사용허가여부 관리비 업로드  \
# 0  262.0                   임의  2022-11-17 13:00:29.0      Y       N
#
#          좌표X        좌표Y                  단지신청일    target is_test
# 0  127.05721  37.476763  2022-11-17 10:19:06.0  124000.0       0
#
# [1 rows x 53 columns]
#        노드 ID  정류소번호     정류소명         X좌표        Y좌표 정류소 타입
# 0  100000001   1001  종로2가사거리  126.987752  37.569808   중앙차로
#    역사_ID 역사명   호선         위도          경도
# 0   9996  미사  5호선  37.560927  127.193877

# %%
# 버스 정류장과 지하철역 데이터 전처리
bus_gdf = preprocess_data(dt_bus, 'X좌표', 'Y좌표')  # 버스 정류장 좌표계 변환
bus_gdf.head(2)
# Out:
#        노드 ID  정류소번호         정류소명         X좌표        Y좌표 정류소 타입  \
# 0  100000001   1001      종로2가사거리  126.987752  37.569808   중앙차로
# 1  100000002   1002  창경궁.서울대학교병원  126.996566  37.579183   중앙차로
#
#                          geometry
# 0   POINT (954764.39 1952394.348)
# 1  POINT (955548.315 1953430.255)

# %%
# 지하철 데이터는 위도, 경도 데이터를 X, Y로 변환
subway_gdf = preprocess_data(dt_subway, '경도', '위도')  # 지하철 데이터도 동일하게 좌표 변환
subway_gdf.head(2)
# Out:
#    역사_ID 역사명   호선         위도          경도                        geometry
# 0   9996  미사  5호선  37.560927  127.193877  POINT (972963.732 1951329.788)
# 1   9995  강일  5호선  37.557490  127.175930  POINT (971377.365 1950953.787)

# %%
# 반경 설정
bus_radius = 500  # 미터 단위
subway_radius = 4000  # 1km를 미터 단위로 표현

# 청크 크기 설정
chunk_size = 10000

# %%
print("버스 정류장 밀도 계산 중 (500m 반경)...")
concat['bus_stop_density_500m'] = process_in_chunks(concat, bus_gdf, bus_radius, chunk_size)

print("지하철역 밀도 계산 중 (1km 반경)...")
concat['subway_station_density_1km'] = process_in_chunks(concat, subway_gdf, subway_radius, chunk_size)

# 결과 출력
print(concat[['좌표X', '좌표Y', 'bus_stop_density_500m', 'subway_station_density_1km']].head())
# Out:
# 버스 정류장 밀도 계산 중 (500m 반경)...
#   0%|          | 0/113 [00:00<?, ?it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#   1%|          | 1/113 [00:00<00:57,  1.94it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#   2%|▏         | 2/113 [00:01<00:56,  1.95it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#   3%|▎         | 3/113 [00:01<00:56,  1.96it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#   4%|▎         | 4/113 [00:02<00:54,  1.98it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#   4%|▍         | 5/113 [00:02<00:55,  1.95it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#   5%|▌         | 6/113 [00:03<00:59,  1.81it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#   6%|▌         | 7/113 [00:03<00:58,  1.82it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#   7%|▋         | 8/113 [00:04<00:55,  1.88it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#   8%|▊         | 9/113 [00:04<00:54,  1.89it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#   9%|▉         | 10/113 [00:05<00:53,  1.91it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  10%|▉         | 11/113 [00:05<00:52,  1.93it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  11%|█         | 12/113 [00:06<00:52,  1.93it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  12%|█▏        | 13/113 [00:06<00:54,  1.83it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  12%|█▏        | 14/113 [00:07<00:52,  1.88it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  13%|█▎        | 15/113 [00:07<00:51,  1.90it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  14%|█▍        | 16/113 [00:08<00:50,  1.93it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  15%|█▌        | 17/113 [00:08<00:49,  1.93it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  16%|█▌        | 18/113 [00:09<00:49,  1.92it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  17%|█▋        | 19/113 [00:09<00:48,  1.94it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  18%|█▊        | 20/113 [00:10<00:50,  1.83it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  19%|█▊        | 21/113 [00:11<00:49,  1.87it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  19%|█▉        | 22/113 [00:11<00:48,  1.86it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  20%|██        | 23/113 [00:12<00:47,  1.90it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  21%|██        | 24/113 [00:12<00:46,  1.92it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  22%|██▏       | 25/113 [00:13<00:45,  1.93it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  23%|██▎       | 26/113 [00:13<00:44,  1.95it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  24%|██▍       | 27/113 [00:14<00:46,  1.84it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  25%|██▍       | 28/113 [00:14<00:45,  1.86it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  26%|██▌       | 29/113 [00:15<00:44,  1.89it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  27%|██▋       | 30/113 [00:15<00:42,  1.93it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  27%|██▋       | 31/113 [00:16<00:42,  1.93it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  28%|██▊       | 32/113 [00:16<00:41,  1.95it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  29%|██▉       | 33/113 [00:17<00:40,  1.96it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  30%|███       | 34/113 [00:17<00:42,  1.85it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  31%|███       | 35/113 [00:18<00:41,  1.87it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  32%|███▏      | 36/113 [00:18<00:41,  1.88it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  33%|███▎      | 37/113 [00:19<00:40,  1.89it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  34%|███▎      | 38/113 [00:19<00:39,  1.91it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  35%|███▍      | 39/113 [00:20<00:38,  1.92it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  35%|███▌      | 40/113 [00:21<00:37,  1.94it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  36%|███▋      | 41/113 [00:21<00:38,  1.85it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  37%|███▋      | 42/113 [00:22<00:37,  1.88it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#
  1.31it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  73%|███████▎  | 83/113 [01:04<00:23,  1.26it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  74%|███████▍  | 84/113 [01:04<00:23,  1.25it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  75%|███████▌  | 85/113 [01:05<00:22,  1.27it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  76%|███████▌  | 86/113 [01:06<00:20,  1.31it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  77%|███████▋  | 87/113 [01:07<00:19,  1.31it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  78%|███████▊  | 88/113 [01:07<00:19,  1.32it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  79%|███████▉  | 89/113 [01:08<00:18,  1.31it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  80%|███████▉  | 90/113 [01:09<00:18,  1.26it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  81%|████████  | 91/113 [01:10<00:17,  1.27it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  81%|████████▏ | 92/113 [01:11<00:16,  1.29it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  82%|████████▏ | 93/113 [01:11<00:15,  1.30it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  83%|████████▎ | 94/113 [01:12<00:14,  1.30it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  84%|████████▍ | 95/113 [01:13<00:13,  1.29it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  85%|████████▍ | 96/113 [01:14<00:13,  1.30it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  86%|████████▌ | 97/113 [01:15<00:12,  1.25it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  87%|████████▋ | 98/113 [01:15<00:11,  1.27it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  88%|████████▊ | 99/113 [01:16<00:10,  1.28it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  88%|████████▊ | 100/113 [01:17<00:10,  1.29it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  89%|████████▉ | 101/113 [01:18<00:09,  1.29it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  90%|█████████ | 102/113 [01:18<00:08,  1.31it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  91%|█████████ | 103/113 [01:19<00:07,  1.30it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  92%|█████████▏| 104/113 [01:20<00:07,  1.24it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  93%|█████████▎| 105/113 [01:21<00:06,  1.26it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  94%|█████████▍| 106/113 [01:22<00:05,  1.26it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  95%|█████████▍| 107/113 [01:22<00:04,  1.27it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  96%|█████████▌| 108/113 [01:23<00:03,  1.28it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  96%|█████████▋| 109/113 [01:24<00:03,  1.29it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  97%|█████████▋| 110/113 [01:25<00:02,  1.30it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  98%|█████████▊| 111/113 [01:26<00:01,  1.25it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
#  99%|█████████▉| 112/113 [01:26<00:00,  1.25it/s]/tmp/ipykernel_495348/1140538833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geometry'] = df.apply(lambda row: Point(project(row[x_col], row[y_col])), axis=1)
# 100%|██████████| 113/113 [01:27<00:00,  1.29it/s]
#          좌표X        좌표Y  bus_stop_density_500m  subway_station_density_1km
# 0  127.05721  37.476763                     13                          25
# 1  127.05721  37.476763                     13                          25
# 2  127.05721  37.476763                     13                          25
# 3  127.05721  37.476763                     13                          25
# 4  127.05721  37.476763                     13                          25

# %%
# 가중치를 적용:
bus_weight = 0.5  # 예: 버스 밀도에 가중치 0.5
subway_weight = 0.8  # 예: 지하철 밀도에 가중치 0.7

concat['대중교통가중치'] = (concat['bus_stop_density_500m'] * bus_weight + 
                                       concat['subway_station_density_1km'] * subway_weight)
                                       
concat= concat.drop(columns=['bus_stop_density_500m','subway_station_density_1km'])

# %%
concat.shape
print(concat.columns)
# Out:
# Index(['시군구', '번지', '본번', '부번', '아파트명', '전용면적', '계약년월', '계약일', '층', '건축년도',
#        '도로명', '해제사유발생일', '등기신청일자', '거래유형', '중개사소재지', 'k-단지분류(아파트,주상복합등등)',
#        'k-전화번호', 'k-팩스번호', '단지소개기존clob', 'k-세대타입(분양형태)', 'k-관리방식', 'k-복도유형',
#        'k-난방방식', 'k-전체동수', 'k-전체세대수', 'k-건설사(시공사)', 'k-시행사', 'k-사용검사일-사용승인일',
#        'k-연면적', 'k-주거전용면적', 'k-관리비부과면적', 'k-전용면적별세대현황(60㎡이하)',
#        'k-전용면적별세대현황(60㎡~85㎡이하)', 'k-85㎡~135㎡이하', 'k-135㎡초과', 'k-홈페이지',
#        'k-등록일자', 'k-수정일자', '고용보험관리번호', '경비비관리형태', '세대전기계약방법', '청소비관리형태',
#        '건축면적', '주차대수', '기타/의무/임대/임의=1/2/3/4', '단지승인일', '사용허가여부', '관리비 업로드',
#        '좌표X', '좌표Y', '단지신청일', 'target', 'is_test', '대중교통가중치'],
#       dtype='object')

# %%
concat.head(1)
# Out:
#              시군구     번지     본번   부번    아파트명   전용면적    계약년월  계약일  층  건축년도  ...  \
# 0  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  79.97  201712    8  3  1987  ...
#
#   기타/의무/임대/임의=1/2/3/4                  단지승인일  사용허가여부 관리비 업로드        좌표X  \
# 0                  임의  2022-11-17 13:00:29.0       Y       N  127.05721
#
#          좌표Y                  단지신청일    target  is_test 대중교통가중치
# 0  37.476763  2022-11-17 10:19:06.0  124000.0        0    26.5
#
# [1 rows x 54 columns]

# %%
concat.to_csv("../trainTestLatLngBusSubway.csv")
